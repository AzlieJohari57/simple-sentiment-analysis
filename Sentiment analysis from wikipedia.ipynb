# %%
import mwclient
import time

site = mwclient.Site('en.wikipedia.org')
page = site.pages['Apple Inc.']

# %%
revs = list(page.revisions())

# %%
# most recent edit 
revs[0]
# Out:
# OrderedDict([('revid', 1237626086),
#              ('parentid', 1237359266),
#              ('user', 'Varoart2005'),
#              ('timestamp',
#               time.struct_time(tm_year=2024, tm_mon=7, tm_mday=30, tm_hour=18, tm_min=23, tm_sec=42, tm_wday=1, tm_yday=212, tm_isdst=-1)),
#              ('comment', '/* Ownership */')])

# %%
revs = sorted(revs, key=lambda rev: rev["timestamp"])

# %%
revs[0]
# Out:
# OrderedDict([('revid', 234249),
#              ('parentid', 0),
#              ('user', '212.53.104.xxx'),
#              ('anon', ''),
#              ('timestamp',
#               time.struct_time(tm_year=2001, tm_mon=11, tm_mday=3, tm_hour=13, tm_min=19, tm_sec=6, tm_wday=5, tm_yday=307, tm_isdst=-1)),
#              ('comment', '*')])

# %%
# load sentiment model 

from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis")

def find_sentiment(text):
    sent = sentiment_pipeline([text[:250]])[0]
    score = sent["score"]
    if sent["label"] == "NEGATIVE":
        score *= -1
    return score
# Out:
# C:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\lite\python\util.py:52: DeprecationWarning: jax.xla_computation is deprecated. Please use the AOT APIs.
#   from jax import xla_computation as _xla_computation
# C:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\lite\python\util.py:52: DeprecationWarning: jax.xla_computation is deprecated. Please use the AOT APIs.
#   from jax import xla_computation as _xla_computation
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.
# C:\Users\Acer\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
find_sentiment("I love you")
# Out:
# 0.9998656511306763

# %%
find_sentiment("neutral")
# Out:
# -0.9992249011993408

# %%
edits = {}

for rev in revs:
    # Convert the timestamp to a formatted date string (YYYY-MM-DD)
    date = time.strftime("%Y-%m-%d", rev["timestamp"])
    
    # Initialize a new entry in the 'edits' dictionary if the date does not already exist
    if date not in edits:
        edits[date] = dict(sentiments=list(), edit_count=0)
    
    # Increment the edit count for the current date
    edits[date]["edit_count"] += 1
    
    # Retrieve the comment from the revision, defaulting to an empty string if not found
    comment = rev.get("comment", "")
    
    # Analyze the sentiment of the comment and add it to the list of sentiments for the current date
    edits[date]["sentiments"].append(find_sentiment(comment))

# %%
from statistics import mean

for key in edits:
    # Check if there are any sentiments recorded for the current date
    if len(edits[key]["sentiments"]) > 0:
        # Calculate the average sentiment for the current date
        edits[key]["sentiment"] = mean(edits[key]["sentiments"])
        
        # Calculate the proportion of negative sentiments (sentiments less than 0)
        edits[key]["neg_sentiment"] = len([s for s in edits[key]["sentiments"] if s < 0]) / len(edits[key]["sentiments"])
    else:
        # If there are no sentiments, set sentiment values to 0
        edits[key]["sentiment"] = 0
        edits[key]["neg_sentiment"] = 0
    
    # Remove the 'sentiments' list from the dictionary as it's no longer needed
    del edits[key]["sentiments"]

# %%
edits
# Out:
# {'2001-11-03': {'edit_count': 2,
#   'sentiment': 0.9885351061820984,
#   'neg_sentiment': 0.0},
#  '2002-02-09': {'edit_count': 1,
#   'sentiment': 0.6330787539482117,
#   'neg_sentiment': 0.0},
#  '2002-02-11': {'edit_count': 2,
#   'sentiment': 0.8641649484634399,
#   'neg_sentiment': 0.0},
#  '2002-02-25': {'edit_count': 1,
#   'sentiment': 0.9796351790428162,
#   'neg_sentiment': 0.0},
#  '2002-03-01': {'edit_count': 3,
#   'sentiment': 0.34675365686416626,
#   'neg_sentiment': 0.3333333333333333},
#  '2002-03-20': {'edit_count': 1,
#   'sentiment': 0.9803916215896606,
#   'neg_sentiment': 0.0},
#  '2002-05-23': {'edit_count': 3,
#   'sentiment': 0.3432354728380839,
#   'neg_sentiment': 0.3333333333333333},
#  '2002-06-01': {'edit_count': 6,
#   'sentiment': 0.9803916215896606,
#   'neg_sentiment': 0.0},
#  '2002-06-06': {'edit_count': 2,
#   'sentiment': 0.9803916215896606,
#   'neg_sentiment': 0.0},
#  '2002-06-11': {'edit_count': 2,
#   'sentiment': -0.007433682680130005,
#   'neg_sentiment': 0.5},
#  '2002-07-05': {'edit_count': 1,
#   'sentiment': 0.9803916215896606,
#   'neg_sentiment': 0.0},
#  '2002-07-10': {'edit_count': 1,
#   'sentiment': 0.9803916215896606,
#   'neg_sentiment': 0.0},
#  '2002-08-04': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2002-08-16': {'edit_count': 1,
#   'sentiment': -0.5290276408195496,
#   'neg_sentiment': 1.0},
#  '2002-09-08': {'edit_count': 1,
#   'sentiment': -0.6853691339492798,
#   'neg_sentiment': 1.0},
#  '2002-09-19': {'edit_count': 1,
#   'sentiment': -0.9840450286865234,
#   'neg_sentiment': 1.0},
#  '2002-09-20': {'edit_count': 1,
#   'sentiment': -0.9938753247261047,
#   'neg_sentiment': 1.0},
#  '2002-10-08': {'edit_count': 2,
#   'sentiment': 0.8974342346191406,
#   'neg_sentiment': 0.0},
#  '2002-10-13': {'edit_count': 3,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2002-12-18': {'edit_count': 1,
#   'sentiment': 0.9514777064323425,
#   'neg_sentiment': 0.0},
#  '2003-01-10': {'edit_count': 1,
#   'sentiment': 0.7703125476837158,
#   'neg_sentiment': 0.0},
#  '2003-02-04': {'edit_count': 1,
#   'sentiment': 0.9695567488670349,
#   'neg_sentiment': 0.0},
#  '2003-02-16': {'edit_count': 1,
#   'sentiment': 0.5007845163345337,
#   'neg_sentiment': 0.0},
#  '2003-02-25': {'edit_count': 1,
#   'sentiment': -0.9769194722175598,
#   'neg_sentiment': 1.0},
#  '2003-03-24': {'edit_count': 1,
#   'sentiment': -0.6533510684967041,
#   'neg_sentiment': 1.0},
#  '2003-03-27': {'edit_count': 2,
#   'sentiment': 0.8702961802482605,
#   'neg_sentiment': 0.0},
#  '2003-04-01': {'edit_count': 1,
#   'sentiment': 0.8965127468109131,
#   'neg_sentiment': 0.0},
#  '2003-04-21': {'edit_count': 1,
#   'sentiment': 0.8964567184448242,
#   'neg_sentiment': 0.0},
#  '2003-04-29': {'edit_count': 2,
#   'sentiment': -0.12557247281074524,
#   'neg_sentiment': 0.5},
#  '2003-05-27': {'edit_count': 5,
#   'sentiment': -0.2652526140213013,
#   'neg_sentiment': 0.6},
#  '2003-06-01': {'edit_count': 1,
#   'sentiment': -0.8286764621734619,
#   'neg_sentiment': 1.0},
#  '2003-06-05': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2003-06-30': {'edit_count': 2,
#   'sentiment': -0.11933663487434387,
#   'neg_sentiment': 0.5},
#  '2003-07-12': {'edit_count': 4,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2003-07-22': {'edit_count': 1,
#   'sentiment': 0.9884997010231018,
#   'neg_sentiment': 0.0},
#  '2003-08-06': {'edit_count': 1,
#   'sentiment': -0.9996260404586792,
#   'neg_sentiment': 1.0},
#  '2003-08-07': {'edit_count': 7,
#   'sentiment': 0.5072203959737506,
#   'neg_sentiment': 0.14285714285714285},
#  '2003-08-08': {'edit_count': 2,
#   'sentiment': 0.0014767348766326904,
#   'neg_sentiment': 0.5},
#  '2003-08-10': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2003-08-12': {'edit_count': 3,
#   'sentiment': 0.8261788686116537,
#   'neg_sentiment': 0.0},
#  '2003-08-13': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2003-08-14': {'edit_count': 1,
#   'sentiment': -0.9798778891563416,
#   'neg_sentiment': 1.0},
#  '2003-08-15': {'edit_count': 5,
#   'sentiment': -0.6450058937072753,
#   'neg_sentiment': 0.8},
#  '2003-08-19': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2003-08-25': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2003-08-26': {'edit_count': 2,
#   'sentiment': -0.08038973808288574,
#   'neg_sentiment': 0.5},
#  '2003-08-31': {'edit_count': 2,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2003-09-01': {'edit_count': 1,
#   'sentiment': 0.9900273680686951,
#   'neg_sentiment': 0.0},
#  '2003-09-13': {'edit_count': 3,
#   'sentiment': -0.32215038935343426,
#   'neg_sentiment': 0.6666666666666666},
#  '2003-09-25': {'edit_count': 1,
#   'sentiment': -0.8174691200256348,
#   'neg_sentiment': 1.0},
#  '2003-10-07': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2003-10-12': {'edit_count': 1,
#   'sentiment': -0.5819266438484192,
#   'neg_sentiment': 1.0},
#  '2003-10-14': {'edit_count': 3,
#   'sentiment': 0.3273296157519023,
#   'neg_sentiment': 0.3333333333333333},
#  '2003-10-16': {'edit_count': 3,
#   'sentiment': 0.3366647760073344,
#   'neg_sentiment': 0.3333333333333333},
#  '2003-10-18': {'edit_count': 1,
#   'sentiment': -0.8020250797271729,
#   'neg_sentiment': 1.0},
#  '2003-10-20': {'edit_count': 1,
#   'sentiment': -0.7029610276222229,
#   'neg_sentiment': 1.0},
#  '2003-10-21': {'edit_count': 2,
#   'sentiment': -0.1253003180027008,
#   'neg_sentiment': 0.5},
#  '2003-10-24': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2003-11-04': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2003-11-10': {'edit_count': 2,
#   'sentiment': -0.12569665908813477,
#   'neg_sentiment': 0.5},
#  '2003-11-22': {'edit_count': 2,
#   'sentiment': -0.1080993115901947,
#   'neg_sentiment': 0.5},
#  '2003-11-25': {'edit_count': 2,
#   'sentiment': 0.041777074337005615,
#   'neg_sentiment': 0.5},
#  '2003-11-28': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2003-11-30': {'edit_count': 2,
#   'sentiment': -0.2341035008430481,
#   'neg_sentiment': 0.5},
#  '2003-12-03': {'edit_count': 1,
#   'sentiment': 0.9300572872161865,
#   'neg_sentiment': 0.0},
#  '2003-12-07': {'edit_count': 3,
#   'sentiment': -0.4141709605852763,
#   'neg_sentiment': 0.6666666666666666},
#  '2003-12-11': {'edit_count': 2,
#   'sentiment': -0.09696725010871887,
#   'neg_sentiment': 0.5},
#  '2003-12-13': {'edit_count': 3,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2003-12-24': {'edit_count': 5,
#   'sentiment': 0.15281535387039186,
#   'neg_sentiment': 0.4},
#  '2004-01-05': {'edit_count': 8,
#   'sentiment': 0.628521203994751,
#   'neg_sentiment': 0.125},
#  '2004-01-09': {'edit_count': 1,
#   'sentiment': 0.9919310212135315,
#   'neg_sentiment': 0.0},
#  '2004-01-10': {'edit_count': 2,
#   'sentiment': 0.867301344871521,
#   'neg_sentiment': 0.0},
#  '2004-01-13': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-01-16': {'edit_count': 2,
#   'sentiment': 0.9967163503170013,
#   'neg_sentiment': 0.0},
#  '2004-01-17': {'edit_count': 1,
#   'sentiment': 0.6177239418029785,
#   'neg_sentiment': 0.0},
#  '2004-01-25': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-01-26': {'edit_count': 2,
#   'sentiment': -0.9889635145664215,
#   'neg_sentiment': 1.0},
#  '2004-01-28': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-01-30': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-02-02': {'edit_count': 1,
#   'sentiment': -0.9879569411277771,
#   'neg_sentiment': 1.0},
#  '2004-02-03': {'edit_count': 2,
#   'sentiment': -0.11942881345748901,
#   'neg_sentiment': 0.5},
#  '2004-02-06': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-02-07': {'edit_count': 1,
#   'sentiment': -0.9902855753898621,
#   'neg_sentiment': 1.0},
#  '2004-02-08': {'edit_count': 2,
#   'sentiment': -0.9631235897541046,
#   'neg_sentiment': 1.0},
#  '2004-02-15': {'edit_count': 2,
#   'sentiment': -0.003333359956741333,
#   'neg_sentiment': 0.5},
#  '2004-02-24': {'edit_count': 1,
#   'sentiment': -0.9991496801376343,
#   'neg_sentiment': 1.0},
#  '2004-02-29': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-03-01': {'edit_count': 3,
#   'sentiment': 0.33048198620478314,
#   'neg_sentiment': 0.3333333333333333},
#  '2004-03-03': {'edit_count': 2,
#   'sentiment': -0.953087717294693,
#   'neg_sentiment': 1.0},
#  '2004-03-05': {'edit_count': 2,
#   'sentiment': 0.87296262383461,
#   'neg_sentiment': 0.0},
#  '2004-03-06': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-03-07': {'edit_count': 1,
#   'sentiment': 0.9957835674285889,
#   'neg_sentiment': 0.0},
#  '2004-03-09': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-03-10': {'edit_count': 2,
#   'sentiment': -0.1256469488143921,
#   'neg_sentiment': 0.5},
#  '2004-03-12': {'edit_count': 1,
#   'sentiment': -0.9895125031471252,
#   'neg_sentiment': 1.0},
#  '2004-03-13': {'edit_count': 2,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-03-14': {'edit_count': 4,
#   'sentiment': 0.6870449334383011,
#   'neg_sentiment': 0.0},
#  '2004-03-15': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-03-17': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-03-19': {'edit_count': 1,
#   'sentiment': -0.9349859356880188,
#   'neg_sentiment': 1.0},
#  '2004-03-21': {'edit_count': 1,
#   'sentiment': 0.9690244197845459,
#   'neg_sentiment': 0.0},
#  '2004-03-24': {'edit_count': 3,
#   'sentiment': 0.3972465395927429,
#   'neg_sentiment': 0.3333333333333333},
#  '2004-03-27': {'edit_count': 1,
#   'sentiment': -0.605063796043396,
#   'neg_sentiment': 1.0},
#  '2004-03-30': {'edit_count': 1,
#   'sentiment': -0.9126003980636597,
#   'neg_sentiment': 1.0},
#  '2004-04-01': {'edit_count': 4,
#   'sentiment': 0.36097459495067596,
#   'neg_sentiment': 0.25},
#  '2004-04-02': {'edit_count': 1,
#   'sentiment': -0.9017959833145142,
#   'neg_sentiment': 1.0},
#  '2004-04-03': {'edit_count': 1,
#   'sentiment': -0.9986974596977234,
#   'neg_sentiment': 1.0},
#  '2004-04-08': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-04-12': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-04-25': {'edit_count': 1,
#   'sentiment': -0.9825659990310669,
#   'neg_sentiment': 1.0},
#  '2004-04-26': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-05-08': {'edit_count': 1,
#   'sentiment': 0.9642617702484131,
#   'neg_sentiment': 0.0},
#  '2004-05-10': {'edit_count': 1,
#   'sentiment': 0.9961521029472351,
#   'neg_sentiment': 0.0},
#  '2004-05-11': {'edit_count': 2,
#   'sentiment': 0.09154075384140015,
#   'neg_sentiment': 0.5},
#  '2004-05-14': {'edit_count': 3,
#   'sentiment': -0.40916242202123004,
#   'neg_sentiment': 0.6666666666666666},
#  '2004-05-28': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-05-30': {'edit_count': 2,
#   'sentiment': -0.12415021657943726,
#   'neg_sentiment': 0.5},
#  '2004-05-31': {'edit_count': 2,
#   'sentiment': -0.12407925724983215,
#   'neg_sentiment': 0.5},
#  '2004-06-01': {'edit_count': 2,
#   'sentiment': -0.9732007384300232,
#   'neg_sentiment': 1.0},
#  '2004-06-03': {'edit_count': 1,
#   'sentiment': -0.8139243721961975,
#   'neg_sentiment': 1.0},
#  '2004-06-04': {'edit_count': 2,
#   'sentiment': 0.1376507580280304,
#   'neg_sentiment': 0.5},
#  '2004-06-06': {'edit_count': 2,
#   'sentiment': 0.9189426898956299,
#   'neg_sentiment': 0.0},
#  '2004-06-11': {'edit_count': 1,
#   'sentiment': -0.9561790823936462,
#   'neg_sentiment': 1.0},
#  '2004-06-14': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-06-17': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-06-18': {'edit_count': 9,
#   'sentiment': 0.0337973435719808,
#   'neg_sentiment': 0.4444444444444444},
#  '2004-06-21': {'edit_count': 2,
#   'sentiment': -0.9574366211891174,
#   'neg_sentiment': 1.0},
#  '2004-06-26': {'edit_count': 2,
#   'sentiment': 0.016193509101867676,
#   'neg_sentiment': 0.5},
#  '2004-06-28': {'edit_count': 3,
#   'sentiment': -0.32413436969121295,
#   'neg_sentiment': 0.6666666666666666},
#  '2004-07-06': {'edit_count': 2,
#   'sentiment': 0.9748721420764923,
#   'neg_sentiment': 0.0},
#  '2004-07-08': {'edit_count': 2,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-07-10': {'edit_count': 1,
#   'sentiment': -0.9889889359474182,
#   'neg_sentiment': 1.0},
#  '2004-07-11': {'edit_count': 1,
#   'sentiment': -0.7528420686721802,
#   'neg_sentiment': 1.0},
#  '2004-07-13': {'edit_count': 1,
#   'sentiment': -0.9969601631164551,
#   'neg_sentiment': 1.0},
#  '2004-07-14': {'edit_count': 2,
#   'sentiment': -0.9748020768165588,
#   'neg_sentiment': 1.0},
#  '2004-07-15': {'edit_count': 2,
#   'sentiment': 0.9735658168792725,
#   'neg_sentiment': 0.0},
#  '2004-07-20': {'edit_count': 3,
#   'sentiment': -0.3197331627209981,
#   'neg_sentiment': 0.6666666666666666},
#  '2004-07-21': {'edit_count': 1,
#   'sentiment': -0.7567573189735413,
#   'neg_sentiment': 1.0},
#  '2004-07-22': {'edit_count': 1,
#   'sentiment': -0.9867187142372131,
#   'neg_sentiment': 1.0},
#  '2004-07-23': {'edit_count': 2,
#   'sentiment': 0.8608434200286865,
#   'neg_sentiment': 0.0},
#  '2004-07-25': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-07-27': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-07-29': {'edit_count': 1,
#   'sentiment': 0.9624136090278625,
#   'neg_sentiment': 0.0},
#  '2004-07-30': {'edit_count': 1,
#   'sentiment': 0.924726665019989,
#   'neg_sentiment': 0.0},
#  '2004-08-03': {'edit_count': 1,
#   'sentiment': -0.7567573189735413,
#   'neg_sentiment': 1.0},
#  '2004-08-04': {'edit_count': 1,
#   'sentiment': -0.9993590712547302,
#   'neg_sentiment': 1.0},
#  '2004-08-05': {'edit_count': 1,
#   'sentiment': -0.9857701063156128,
#   'neg_sentiment': 1.0},
#  '2004-08-06': {'edit_count': 3,
#   'sentiment': 0.9506902098655701,
#   'neg_sentiment': 0.0},
#  '2004-08-11': {'edit_count': 3,
#   'sentiment': 0.24776768684387207,
#   'neg_sentiment': 0.3333333333333333},
#  '2004-08-12': {'edit_count': 1,
#   'sentiment': -0.9951626062393188,
#   'neg_sentiment': 1.0},
#  '2004-08-13': {'edit_count': 9,
#   'sentiment': -0.5750361945894029,
#   'neg_sentiment': 0.7777777777777778},
#  '2004-08-15': {'edit_count': 1,
#   'sentiment': 0.9735658168792725,
#   'neg_sentiment': 0.0},
#  '2004-08-17': {'edit_count': 4,
#   'sentiment': 0.9063649028539658,
#   'neg_sentiment': 0.0},
#  '2004-08-19': {'edit_count': 5,
#   'sentiment': -0.9831665873527526,
#   'neg_sentiment': 1.0},
#  '2004-08-20': {'edit_count': 11,
#   'sentiment': -0.32122762636704877,
#   'neg_sentiment': 0.6363636363636364},
#  '2004-08-21': {'edit_count': 7,
#   'sentiment': -0.738229010786329,
#   'neg_sentiment': 0.8571428571428571},
#  '2004-08-23': {'edit_count': 2,
#   'sentiment': -0.9803251624107361,
#   'neg_sentiment': 1.0},
#  '2004-08-24': {'edit_count': 5,
#   'sentiment': 0.15040019750595093,
#   'neg_sentiment': 0.4},
#  '2004-08-27': {'edit_count': 1,
#   'sentiment': -0.9943822622299194,
#   'neg_sentiment': 1.0},
#  '2004-08-28': {'edit_count': 1,
#   'sentiment': 0.862769603729248,
#   'neg_sentiment': 0.0},
#  '2004-08-30': {'edit_count': 2,
#   'sentiment': -0.9990598857402802,
#   'neg_sentiment': 1.0},
#  '2004-09-01': {'edit_count': 1,
#   'sentiment': 0.9506902098655701,
#   'neg_sentiment': 0.0},
#  '2004-09-02': {'edit_count': 3,
#   'sentiment': -0.3298121889432271,
#   'neg_sentiment': 0.6666666666666666},
#  '2004-09-03': {'edit_count': 1,
#   'sentiment': 0.9862136244773865,
#   'neg_sentiment': 0.0},
#  '2004-09-07': {'edit_count': 3,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-09-09': {'edit_count': 2,
#   'sentiment': -0.8578009903430939,
#   'neg_sentiment': 1.0},
#  '2004-09-12': {'edit_count': 1,
#   'sentiment': -0.8812606930732727,
#   'neg_sentiment': 1.0},
#  '2004-09-14': {'edit_count': 2,
#   'sentiment': 0.9859834015369415,
#   'neg_sentiment': 0.0},
#  '2004-09-18': {'edit_count': 5,
#   'sentiment': 0.4913309931755066,
#   'neg_sentiment': 0.2},
#  '2004-09-20': {'edit_count': 4,
#   'sentiment': -0.5612228214740753,
#   'neg_sentiment': 0.75},
#  '2004-09-22': {'edit_count': 3,
#   'sentiment': -0.931617259979248,
#   'neg_sentiment': 1.0},
#  '2004-09-23': {'edit_count': 2,
#   'sentiment': -0.9996257126331329,
#   'neg_sentiment': 1.0},
#  '2004-09-24': {'edit_count': 3,
#   'sentiment': -0.32904934883117676,
#   'neg_sentiment': 0.6666666666666666},
#  '2004-09-26': {'edit_count': 1,
#   'sentiment': 0.9735658168792725,
#   'neg_sentiment': 0.0},
#  '2004-09-30': {'edit_count': 1,
#   'sentiment': -0.920997142791748,
#   'neg_sentiment': 1.0},
#  '2004-10-01': {'edit_count': 1,
#   'sentiment': 0.9735658168792725,
#   'neg_sentiment': 0.0},
#  '2004-10-02': {'edit_count': 3,
#   'sentiment': -0.9728067715962728,
#   'neg_sentiment': 1.0},
#  '2004-10-04': {'edit_count': 3,
#   'sentiment': 0.45735466480255127,
#   'neg_sentiment': 0.3333333333333333},
#  '2004-10-07': {'edit_count': 4,
#   'sentiment': -0.002160981297492981,
#   'neg_sentiment': 0.5},
#  '2004-10-10': {'edit_count': 1,
#   'sentiment': 0.9330029487609863,
#   'neg_sentiment': 0.0},
#  '2004-10-11': {'edit_count': 1,
#   'sentiment': -0.9967789053916931,
#   'neg_sentiment': 1.0},
#  '2004-10-12': {'edit_count': 1,
#   'sentiment': -0.9980085492134094,
#   'neg_sentiment': 1.0},
#  '2004-10-14': {'edit_count': 1,
#   'sentiment': 0.9735658168792725,
#   'neg_sentiment': 0.0},
#  '2004-10-16': {'edit_count': 6,
#   'sentiment': -0.007933706045150757,
#   'neg_sentiment': 0.5},
#  '2004-10-17': {'edit_count': 1,
#   'sentiment': -0.9937484264373779,
#   'neg_sentiment': 1.0},
#  '2004-10-19': {'edit_count': 1,
#   'sentiment': 0.9985474944114685,
#   'neg_sentiment': 0.0},
#  '2004-10-20': {'edit_count': 2,
#   'sentiment': -0.11954653263092041,
#   'neg_sentiment': 0.5},
#  '2004-10-26': {'edit_count': 1,
#   'sentiment': -0.9615564346313477,
#   'neg_sentiment': 1.0},
#  '2004-10-27': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-10-29': {'edit_count': 2,
#   'sentiment': -0.006033182144165039,
#   'neg_sentiment': 0.5},
#  '2004-10-30': {'edit_count': 2,
#   'sentiment': -0.012032270431518555,
#   'neg_sentiment': 0.5},
#  '2004-10-31': {'edit_count': 2,
#   'sentiment': 0.9814791679382324,
#   'neg_sentiment': 0.0},
#  '2004-11-01': {'edit_count': 1,
#   'sentiment': 0.6941739916801453,
#   'neg_sentiment': 0.0},
#  '2004-11-02': {'edit_count': 3,
#   'sentiment': 0.31795928875605267,
#   'neg_sentiment': 0.3333333333333333},
#  '2004-11-03': {'edit_count': 2,
#   'sentiment': -0.12467396259307861,
#   'neg_sentiment': 0.5},
#  '2004-11-06': {'edit_count': 2,
#   'sentiment': -0.14627236127853394,
#   'neg_sentiment': 0.5},
#  '2004-11-07': {'edit_count': 3,
#   'sentiment': -0.43352431058883667,
#   'neg_sentiment': 0.6666666666666666},
#  '2004-11-08': {'edit_count': 2,
#   'sentiment': 0.7383734285831451,
#   'neg_sentiment': 0.0},
#  '2004-11-09': {'edit_count': 9,
#   'sentiment': -0.7692919307284884,
#   'neg_sentiment': 0.8888888888888888},
#  '2004-11-10': {'edit_count': 6,
#   'sentiment': -0.27928463617960614,
#   'neg_sentiment': 0.6666666666666666},
#  '2004-11-11': {'edit_count': 2,
#   'sentiment': 0.1617496907711029,
#   'neg_sentiment': 0.5},
#  '2004-11-12': {'edit_count': 1,
#   'sentiment': -0.999040424823761,
#   'neg_sentiment': 1.0},
#  '2004-11-14': {'edit_count': 3,
#   'sentiment': 0.9061030745506287,
#   'neg_sentiment': 0.0},
#  '2004-11-16': {'edit_count': 3,
#   'sentiment': 0.3161328037579854,
#   'neg_sentiment': 0.3333333333333333},
#  '2004-11-19': {'edit_count': 1,
#   'sentiment': -0.9967789053916931,
#   'neg_sentiment': 1.0},
#  '2004-11-21': {'edit_count': 1,
#   'sentiment': -0.8968585729598999,
#   'neg_sentiment': 1.0},
#  '2004-11-22': {'edit_count': 1,
#   'sentiment': -0.9977218508720398,
#   'neg_sentiment': 1.0},
#  '2004-11-23': {'edit_count': 14,
#   'sentiment': 0.1688039813722883,
#   'neg_sentiment': 0.35714285714285715},
#  '2004-11-25': {'edit_count': 4,
#   'sentiment': 0.37029165029525757,
#   'neg_sentiment': 0.25},
#  '2004-11-26': {'edit_count': 4,
#   'sentiment': -0.50116366147995,
#   'neg_sentiment': 0.75},
#  '2004-11-27': {'edit_count': 4,
#   'sentiment': -0.012295931577682495,
#   'neg_sentiment': 0.5},
#  '2004-11-28': {'edit_count': 2,
#   'sentiment': 0.989146888256073,
#   'neg_sentiment': 0.0},
#  '2004-12-01': {'edit_count': 4,
#   'sentiment': -0.9807886779308319,
#   'neg_sentiment': 1.0},
#  '2004-12-02': {'edit_count': 2,
#   'sentiment': -0.9989486336708069,
#   'neg_sentiment': 1.0},
#  '2004-12-03': {'edit_count': 1,
#   'sentiment': 0.9735658168792725,
#   'neg_sentiment': 0.0},
#  '2004-12-04': {'edit_count': 2,
#   'sentiment': -0.9954788088798523,
#   'neg_sentiment': 1.0},
#  '2004-12-05': {'edit_count': 2,
#   'sentiment': 0.9844304621219635,
#   'neg_sentiment': 0.0},
#  '2004-12-06': {'edit_count': 2,
#   'sentiment': -0.12566104531288147,
#   'neg_sentiment': 0.5},
#  '2004-12-07': {'edit_count': 6,
#   'sentiment': -0.30839595198631287,
#   'neg_sentiment': 0.6666666666666666},
#  '2004-12-08': {'edit_count': 11,
#   'sentiment': 0.06375583193518898,
#   'neg_sentiment': 0.45454545454545453},
#  '2004-12-09': {'edit_count': 2,
#   'sentiment': 0.017322629690170288,
#   'neg_sentiment': 0.5},
#  '2004-12-10': {'edit_count': 1,
#   'sentiment': -0.9967789053916931,
#   'neg_sentiment': 1.0},
#  '2004-12-11': {'edit_count': 2,
#   'sentiment': 0.012688130140304565,
#   'neg_sentiment': 0.5},
#  '2004-12-12': {'edit_count': 2,
#   'sentiment': -0.1257859468460083,
#   'neg_sentiment': 0.5},
#  '2004-12-13': {'edit_count': 3,
#   'sentiment': 0.16623908281326294,
#   'neg_sentiment': 0.3333333333333333},
#  '2004-12-15': {'edit_count': 11,
#   'sentiment': -0.3205382769758051,
#   'neg_sentiment': 0.6363636363636364},
#  '2004-12-16': {'edit_count': 12,
#   'sentiment': -0.6265748788913091,
#   'neg_sentiment': 0.8333333333333334},
#  '2004-12-17': {'edit_count': 1,
#   'sentiment': -0.9840249419212341,
#   'neg_sentiment': 1.0},
#  '2004-12-18': {'edit_count': 1,
#   'sentiment': -0.9989486336708069,
#   'neg_sentiment': 1.0},
#  '2004-12-20': {'edit_count': 1,
#   'sentiment': -0.9990990161895752,
#   'neg_sentiment': 1.0},
#  '2004-12-21': {'edit_count': 9,
#   'sentiment': -0.4594106674194336,
#   'neg_sentiment': 0.7777777777777778},
#  '2004-12-22': {'edit_count': 15,
#   'sentiment': 0.08468599716822306,
#   'neg_sentiment': 0.4666666666666667},
#  '2004-12-24': {'edit_count': 1,
#   'sentiment': -0.8837547302246094,
#   'neg_sentiment': 1.0},
#  '2004-12-25': {'edit_count': 2,
#   'sentiment': -0.8779601752758026,
#   'neg_sentiment': 1.0},
#  '2004-12-26': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2004-12-27': {'edit_count': 1,
#   'sentiment': -0.7412663698196411,
#   'neg_sentiment': 1.0},
#  '2004-12-31': {'edit_count': 2,
#   'sentiment': -0.12462016940116882,
#   'neg_sentiment': 0.5},
#  '2005-01-01': {'edit_count': 4,
#   'sentiment': -0.9163748025894165,
#   'neg_sentiment': 1.0},
#  '2005-01-03': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-01-04': {'edit_count': 3,
#   'sentiment': 0.24486631155014038,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-01-05': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-01-06': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-01-07': {'edit_count': 5,
#   'sentiment': -0.24544235467910766,
#   'neg_sentiment': 0.6},
#  '2005-01-08': {'edit_count': 3,
#   'sentiment': 0.2490826646486918,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-01-11': {'edit_count': 2,
#   'sentiment': -0.9753060936927795,
#   'neg_sentiment': 1.0},
#  '2005-01-12': {'edit_count': 8,
#   'sentiment': -0.49961214512586594,
#   'neg_sentiment': 0.75},
#  '2005-01-14': {'edit_count': 2,
#   'sentiment': 0.7859236598014832,
#   'neg_sentiment': 0.0},
#  '2005-01-18': {'edit_count': 2,
#   'sentiment': -0.024894744157791138,
#   'neg_sentiment': 0.5},
#  '2005-01-19': {'edit_count': 4,
#   'sentiment': -0.494746133685112,
#   'neg_sentiment': 0.75},
#  '2005-01-20': {'edit_count': 3,
#   'sentiment': 0.25739343961079914,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-01-21': {'edit_count': 9,
#   'sentiment': -0.44248075617684257,
#   'neg_sentiment': 0.7777777777777778},
#  '2005-01-23': {'edit_count': 3,
#   'sentiment': 0.2505742907524109,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-01-24': {'edit_count': 2,
#   'sentiment': -0.0008006393909454346,
#   'neg_sentiment': 0.5},
#  '2005-01-25': {'edit_count': 5,
#   'sentiment': 0.16040687561035155,
#   'neg_sentiment': 0.4},
#  '2005-01-26': {'edit_count': 1,
#   'sentiment': -0.7489940524101257,
#   'neg_sentiment': 1.0},
#  '2005-01-27': {'edit_count': 3,
#   'sentiment': 0.22685732444127402,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-01-30': {'edit_count': 2,
#   'sentiment': 0.9735658168792725,
#   'neg_sentiment': 0.0},
#  '2005-01-31': {'edit_count': 2,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-02-01': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-02-02': {'edit_count': 2,
#   'sentiment': 0.7349739372730255,
#   'neg_sentiment': 0.0},
#  '2005-02-03': {'edit_count': 5,
#   'sentiment': -0.1875075340270996,
#   'neg_sentiment': 0.6},
#  '2005-02-04': {'edit_count': 2,
#   'sentiment': 0.12349677085876465,
#   'neg_sentiment': 0.5},
#  '2005-02-05': {'edit_count': 2,
#   'sentiment': 0.9846871793270111,
#   'neg_sentiment': 0.0},
#  '2005-02-06': {'edit_count': 5,
#   'sentiment': 0.15394636392593383,
#   'neg_sentiment': 0.4},
#  '2005-02-08': {'edit_count': 5,
#   'sentiment': 0.18925541639328003,
#   'neg_sentiment': 0.4},
#  '2005-02-10': {'edit_count': 1,
#   'sentiment': -0.9940720200538635,
#   'neg_sentiment': 1.0},
#  '2005-02-12': {'edit_count': 1,
#   'sentiment': -0.9713435173034668,
#   'neg_sentiment': 1.0},
#  '2005-02-13': {'edit_count': 1,
#   'sentiment': -0.9713435173034668,
#   'neg_sentiment': 1.0},
#  '2005-02-16': {'edit_count': 5,
#   'sentiment': 0.3065063714981079,
#   'neg_sentiment': 0.2},
#  '2005-02-18': {'edit_count': 5,
#   'sentiment': -0.9971663355827332,
#   'neg_sentiment': 1.0},
#  '2005-02-23': {'edit_count': 1,
#   'sentiment': 0.934233546257019,
#   'neg_sentiment': 0.0},
#  '2005-02-24': {'edit_count': 2,
#   'sentiment': 0.0290185809135437,
#   'neg_sentiment': 0.5},
#  '2005-02-26': {'edit_count': 3,
#   'sentiment': -0.2684127489725749,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-02-27': {'edit_count': 2,
#   'sentiment': -0.9713435173034668,
#   'neg_sentiment': 1.0},
#  '2005-02-28': {'edit_count': 2,
#   'sentiment': -0.9815115332603455,
#   'neg_sentiment': 1.0},
#  '2005-03-01': {'edit_count': 2,
#   'sentiment': -0.1116112470626831,
#   'neg_sentiment': 0.5},
#  '2005-03-03': {'edit_count': 1,
#   'sentiment': 0.9735658168792725,
#   'neg_sentiment': 0.0},
#  '2005-03-05': {'edit_count': 1,
#   'sentiment': -0.9713435173034668,
#   'neg_sentiment': 1.0},
#  '2005-03-06': {'edit_count': 3,
#   'sentiment': 0.8241104682286581,
#   'neg_sentiment': 0.0},
#  '2005-03-07': {'edit_count': 1,
#   'sentiment': -0.9713435173034668,
#   'neg_sentiment': 1.0},
#  '2005-03-08': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-03-09': {'edit_count': 1,
#   'sentiment': -0.9976420402526855,
#   'neg_sentiment': 1.0},
#  '2005-03-10': {'edit_count': 1,
#   'sentiment': -0.9989486336708069,
#   'neg_sentiment': 1.0},
#  '2005-03-12': {'edit_count': 1,
#   'sentiment': -0.9670782685279846,
#   'neg_sentiment': 1.0},
#  '2005-03-14': {'edit_count': 3,
#   'sentiment': 0.31087011098861694,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-03-15': {'edit_count': 6,
#   'sentiment': -0.3741909861564636,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-03-19': {'edit_count': 2,
#   'sentiment': -0.012567460536956787,
#   'neg_sentiment': 0.5},
#  '2005-03-20': {'edit_count': 5,
#   'sentiment': 0.5863097310066223,
#   'neg_sentiment': 0.2},
#  '2005-03-22': {'edit_count': 2,
#   'sentiment': 0.9756191670894623,
#   'neg_sentiment': 0.0},
#  '2005-03-23': {'edit_count': 3,
#   'sentiment': -0.3362487554550171,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-03-24': {'edit_count': 2,
#   'sentiment': -0.9854210019111633,
#   'neg_sentiment': 1.0},
#  '2005-03-27': {'edit_count': 1,
#   'sentiment': -0.9129661917686462,
#   'neg_sentiment': 1.0},
#  '2005-03-28': {'edit_count': 4,
#   'sentiment': -0.8661645352840424,
#   'neg_sentiment': 1.0},
#  '2005-03-29': {'edit_count': 6,
#   'sentiment': 0.3283320367336273,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-04-01': {'edit_count': 7,
#   'sentiment': 0.38525218623025076,
#   'neg_sentiment': 0.2857142857142857},
#  '2005-04-02': {'edit_count': 2,
#   'sentiment': -0.9786275029182434,
#   'neg_sentiment': 1.0},
#  '2005-04-04': {'edit_count': 1,
#   'sentiment': 0.9506902098655701,
#   'neg_sentiment': 0.0},
#  '2005-04-05': {'edit_count': 4,
#   'sentiment': -0.48142196238040924,
#   'neg_sentiment': 0.75},
#  '2005-04-07': {'edit_count': 4,
#   'sentiment': -0.9886604249477386,
#   'neg_sentiment': 1.0},
#  '2005-04-08': {'edit_count': 13,
#   'sentiment': -0.8111496017529414,
#   'neg_sentiment': 0.9230769230769231},
#  '2005-04-09': {'edit_count': 2,
#   'sentiment': -0.994685709476471,
#   'neg_sentiment': 1.0},
#  '2005-04-11': {'edit_count': 1,
#   'sentiment': 0.9457485675811768,
#   'neg_sentiment': 0.0},
#  '2005-04-12': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-04-13': {'edit_count': 3,
#   'sentiment': -0.3250502149264018,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-04-14': {'edit_count': 6,
#   'sentiment': 0.5186797976493835,
#   'neg_sentiment': 0.16666666666666666},
#  '2005-04-15': {'edit_count': 9,
#   'sentiment': -0.5693397720654806,
#   'neg_sentiment': 0.7777777777777778},
#  '2005-04-16': {'edit_count': 3,
#   'sentiment': 0.3701845010121663,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-04-17': {'edit_count': 6,
#   'sentiment': 0.6112524966398875,
#   'neg_sentiment': 0.16666666666666666},
#  '2005-04-18': {'edit_count': 1,
#   'sentiment': -0.7489940524101257,
#   'neg_sentiment': 1.0},
#  '2005-04-19': {'edit_count': 2,
#   'sentiment': -0.9799495339393616,
#   'neg_sentiment': 1.0},
#  '2005-04-21': {'edit_count': 3,
#   'sentiment': -0.24774593114852905,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-04-22': {'edit_count': 2,
#   'sentiment': -0.8684495389461517,
#   'neg_sentiment': 1.0},
#  '2005-04-23': {'edit_count': 1,
#   'sentiment': 0.570952296257019,
#   'neg_sentiment': 0.0},
#  '2005-04-24': {'edit_count': 2,
#   'sentiment': -0.19379475712776184,
#   'neg_sentiment': 0.5},
#  '2005-04-25': {'edit_count': 4,
#   'sentiment': -0.9315038919448853,
#   'neg_sentiment': 1.0},
#  '2005-04-26': {'edit_count': 1,
#   'sentiment': 0.9300214052200317,
#   'neg_sentiment': 0.0},
#  '2005-04-27': {'edit_count': 2,
#   'sentiment': 0.897634893655777,
#   'neg_sentiment': 0.0},
#  '2005-04-28': {'edit_count': 2,
#   'sentiment': -0.12488165497779846,
#   'neg_sentiment': 0.5},
#  '2005-04-29': {'edit_count': 1,
#   'sentiment': -0.9995599389076233,
#   'neg_sentiment': 1.0},
#  '2005-05-02': {'edit_count': 3,
#   'sentiment': 0.23679381608963013,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-05-04': {'edit_count': 6,
#   'sentiment': 0.6200005908807119,
#   'neg_sentiment': 0.16666666666666666},
#  '2005-05-07': {'edit_count': 2,
#   'sentiment': 0.11247396469116211,
#   'neg_sentiment': 0.5},
#  '2005-05-08': {'edit_count': 1,
#   'sentiment': 0.9813898205757141,
#   'neg_sentiment': 0.0},
#  '2005-05-09': {'edit_count': 2,
#   'sentiment': -0.873746782541275,
#   'neg_sentiment': 1.0},
#  '2005-05-10': {'edit_count': 4,
#   'sentiment': -0.8850327283143997,
#   'neg_sentiment': 1.0},
#  '2005-05-11': {'edit_count': 7,
#   'sentiment': -0.42878200326647076,
#   'neg_sentiment': 0.7142857142857143},
#  '2005-05-12': {'edit_count': 3,
#   'sentiment': -0.42585134506225586,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-05-17': {'edit_count': 11,
#   'sentiment': -0.11449856649745595,
#   'neg_sentiment': 0.5454545454545454},
#  '2005-05-18': {'edit_count': 1,
#   'sentiment': -0.869838535785675,
#   'neg_sentiment': 1.0},
#  '2005-05-19': {'edit_count': 6,
#   'sentiment': -0.9726869861284891,
#   'neg_sentiment': 1.0},
#  '2005-05-20': {'edit_count': 1,
#   'sentiment': -0.9987419247627258,
#   'neg_sentiment': 1.0},
#  '2005-05-21': {'edit_count': 1,
#   'sentiment': 0.6070945262908936,
#   'neg_sentiment': 0.0},
#  '2005-05-24': {'edit_count': 2,
#   'sentiment': -0.8330294787883759,
#   'neg_sentiment': 1.0},
#  '2005-05-27': {'edit_count': 7,
#   'sentiment': 0.5793277536119733,
#   'neg_sentiment': 0.14285714285714285},
#  '2005-05-28': {'edit_count': 2,
#   'sentiment': -0.9350768625736237,
#   'neg_sentiment': 1.0},
#  '2005-05-29': {'edit_count': 2,
#   'sentiment': -0.9905412793159485,
#   'neg_sentiment': 1.0},
#  '2005-05-30': {'edit_count': 2,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-05-31': {'edit_count': 4,
#   'sentiment': 0.08165954053401947,
#   'neg_sentiment': 0.5},
#  '2005-06-02': {'edit_count': 2,
#   'sentiment': -0.004015058279037476,
#   'neg_sentiment': 0.5},
#  '2005-06-03': {'edit_count': 3,
#   'sentiment': -0.39859672387441,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-06-04': {'edit_count': 3,
#   'sentiment': 0.3277440269788106,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-06-05': {'edit_count': 1,
#   'sentiment': 0.9490054249763489,
#   'neg_sentiment': 0.0},
#  '2005-06-06': {'edit_count': 29,
#   'sentiment': 0.30196942543161326,
#   'neg_sentiment': 0.3448275862068966},
#  '2005-06-07': {'edit_count': 18,
#   'sentiment': 0.14632393585311043,
#   'neg_sentiment': 0.4444444444444444},
#  '2005-06-08': {'edit_count': 10,
#   'sentiment': -0.11745667457580566,
#   'neg_sentiment': 0.5},
#  '2005-06-09': {'edit_count': 3,
#   'sentiment': -0.26704434553782147,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-06-10': {'edit_count': 10,
#   'sentiment': 0.3357259273529053,
#   'neg_sentiment': 0.3},
#  '2005-06-11': {'edit_count': 6,
#   'sentiment': 0.613018790880839,
#   'neg_sentiment': 0.16666666666666666},
#  '2005-06-12': {'edit_count': 1,
#   'sentiment': 0.9907005429267883,
#   'neg_sentiment': 0.0},
#  '2005-06-14': {'edit_count': 8,
#   'sentiment': -0.1451907828450203,
#   'neg_sentiment': 0.625},
#  '2005-06-15': {'edit_count': 7,
#   'sentiment': -0.40285653727395193,
#   'neg_sentiment': 0.7142857142857143},
#  '2005-06-16': {'edit_count': 3,
#   'sentiment': -0.18932223320007324,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-06-17': {'edit_count': 3,
#   'sentiment': -0.3317166566848755,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-06-18': {'edit_count': 2,
#   'sentiment': 0.006478250026702881,
#   'neg_sentiment': 0.5},
#  '2005-06-19': {'edit_count': 7,
#   'sentiment': -0.2046139325414385,
#   'neg_sentiment': 0.5714285714285714},
#  '2005-06-20': {'edit_count': 3,
#   'sentiment': -0.32392098506291706,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-06-21': {'edit_count': 7,
#   'sentiment': 0.6616238355636597,
#   'neg_sentiment': 0.14285714285714285},
#  '2005-06-22': {'edit_count': 7,
#   'sentiment': 0.5685921822275434,
#   'neg_sentiment': 0.14285714285714285},
#  '2005-06-25': {'edit_count': 4,
#   'sentiment': -0.407000795006752,
#   'neg_sentiment': 0.75},
#  '2005-06-26': {'edit_count': 2,
#   'sentiment': -0.041829586029052734,
#   'neg_sentiment': 0.5},
#  '2005-06-30': {'edit_count': 2,
#   'sentiment': -0.01576751470565796,
#   'neg_sentiment': 0.5},
#  '2005-07-01': {'edit_count': 13,
#   'sentiment': -0.16800123911637527,
#   'neg_sentiment': 0.5384615384615384},
#  '2005-07-02': {'edit_count': 4,
#   'sentiment': -0.517158254981041,
#   'neg_sentiment': 0.75},
#  '2005-07-04': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-07-06': {'edit_count': 5,
#   'sentiment': -0.16042007207870485,
#   'neg_sentiment': 0.6},
#  '2005-07-09': {'edit_count': 3,
#   'sentiment': 0.08822367588678996,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-07-11': {'edit_count': 3,
#   'sentiment': -0.463705579439799,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-07-12': {'edit_count': 1,
#   'sentiment': 0.9300214052200317,
#   'neg_sentiment': 0.0},
#  '2005-07-13': {'edit_count': 8,
#   'sentiment': -0.13301285356283188,
#   'neg_sentiment': 0.625},
#  '2005-07-14': {'edit_count': 4,
#   'sentiment': -0.9596041142940521,
#   'neg_sentiment': 1.0},
#  '2005-07-16': {'edit_count': 6,
#   'sentiment': -0.07951881488164265,
#   'neg_sentiment': 0.5},
#  '2005-07-18': {'edit_count': 5,
#   'sentiment': -0.15200453996658325,
#   'neg_sentiment': 0.6},
#  '2005-07-20': {'edit_count': 1,
#   'sentiment': -0.7489940524101257,
#   'neg_sentiment': 1.0},
#  '2005-07-22': {'edit_count': 2,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-07-23': {'edit_count': 1,
#   'sentiment': -0.9958807229995728,
#   'neg_sentiment': 1.0},
#  '2005-07-24': {'edit_count': 1,
#   'sentiment': 0.9522356986999512,
#   'neg_sentiment': 0.0},
#  '2005-07-25': {'edit_count': 1,
#   'sentiment': -0.5231730937957764,
#   'neg_sentiment': 1.0},
#  '2005-07-26': {'edit_count': 4,
#   'sentiment': 0.432145431637764,
#   'neg_sentiment': 0.25},
#  '2005-07-27': {'edit_count': 1,
#   'sentiment': 0.9737417697906494,
#   'neg_sentiment': 0.0},
#  '2005-07-28': {'edit_count': 1,
#   'sentiment': -0.9615564346313477,
#   'neg_sentiment': 1.0},
#  '2005-07-29': {'edit_count': 1,
#   'sentiment': -0.9990624785423279,
#   'neg_sentiment': 1.0},
#  '2005-07-30': {'edit_count': 1,
#   'sentiment': -0.9884297847747803,
#   'neg_sentiment': 1.0},
#  '2005-07-31': {'edit_count': 4,
#   'sentiment': -0.8158643692731857,
#   'neg_sentiment': 1.0},
#  '2005-08-01': {'edit_count': 3,
#   'sentiment': -0.9525220592816671,
#   'neg_sentiment': 1.0},
#  '2005-08-02': {'edit_count': 3,
#   'sentiment': -0.301821231842041,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-08-03': {'edit_count': 6,
#   'sentiment': -0.2945748070875804,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-08-04': {'edit_count': 3,
#   'sentiment': 0.3364396293958028,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-08-05': {'edit_count': 3,
#   'sentiment': -0.41501784324645996,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-08-07': {'edit_count': 3,
#   'sentiment': -0.24867254495620728,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-08-08': {'edit_count': 5,
#   'sentiment': -0.2567984819412231,
#   'neg_sentiment': 0.6},
#  '2005-08-09': {'edit_count': 2,
#   'sentiment': -0.9974796772003174,
#   'neg_sentiment': 1.0},
#  '2005-08-10': {'edit_count': 1,
#   'sentiment': -0.9982652068138123,
#   'neg_sentiment': 1.0},
#  '2005-08-11': {'edit_count': 2,
#   'sentiment': -0.8597359657287598,
#   'neg_sentiment': 1.0},
#  '2005-08-12': {'edit_count': 4,
#   'sentiment': -0.4479174166917801,
#   'neg_sentiment': 0.75},
#  '2005-08-13': {'edit_count': 3,
#   'sentiment': 0.2870313922564189,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-08-14': {'edit_count': 1,
#   'sentiment': 0.9300214052200317,
#   'neg_sentiment': 0.0},
#  '2005-08-16': {'edit_count': 1,
#   'sentiment': 0.5210469365119934,
#   'neg_sentiment': 0.0},
#  '2005-08-17': {'edit_count': 4,
#   'sentiment': -0.06351204216480255,
#   'neg_sentiment': 0.5},
#  '2005-08-18': {'edit_count': 2,
#   'sentiment': 0.10182937979698181,
#   'neg_sentiment': 0.5},
#  '2005-08-19': {'edit_count': 6,
#   'sentiment': -0.3326723674933116,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-08-21': {'edit_count': 4,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-08-22': {'edit_count': 1,
#   'sentiment': -0.8531571626663208,
#   'neg_sentiment': 1.0},
#  '2005-08-23': {'edit_count': 6,
#   'sentiment': -0.38435863455136615,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-08-24': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-08-25': {'edit_count': 1,
#   'sentiment': -0.751288890838623,
#   'neg_sentiment': 1.0},
#  '2005-08-26': {'edit_count': 7,
#   'sentiment': -0.5759698578289577,
#   'neg_sentiment': 0.8571428571428571},
#  '2005-08-27': {'edit_count': 1,
#   'sentiment': -0.9615564346313477,
#   'neg_sentiment': 1.0},
#  '2005-08-28': {'edit_count': 4,
#   'sentiment': -0.07791128754615784,
#   'neg_sentiment': 0.5},
#  '2005-08-29': {'edit_count': 1,
#   'sentiment': 0.9506902098655701,
#   'neg_sentiment': 0.0},
#  '2005-08-30': {'edit_count': 1,
#   'sentiment': 0.8269950747489929,
#   'neg_sentiment': 0.0},
#  '2005-08-31': {'edit_count': 5,
#   'sentiment': 0.47497828006744386,
#   'neg_sentiment': 0.2},
#  '2005-09-02': {'edit_count': 1,
#   'sentiment': -0.9967789053916931,
#   'neg_sentiment': 1.0},
#  '2005-09-03': {'edit_count': 1,
#   'sentiment': 0.9300214052200317,
#   'neg_sentiment': 0.0},
#  '2005-09-04': {'edit_count': 1,
#   'sentiment': -0.9781558513641357,
#   'neg_sentiment': 1.0},
#  '2005-09-07': {'edit_count': 2,
#   'sentiment': -0.9883512854576111,
#   'neg_sentiment': 1.0},
#  '2005-09-08': {'edit_count': 8,
#   'sentiment': -0.9750023856759071,
#   'neg_sentiment': 1.0},
#  '2005-09-10': {'edit_count': 2,
#   'sentiment': -0.8473304510116577,
#   'neg_sentiment': 1.0},
#  '2005-09-11': {'edit_count': 3,
#   'sentiment': 0.7907918095588684,
#   'neg_sentiment': 0.0},
#  '2005-09-12': {'edit_count': 6,
#   'sentiment': -0.07638282577196757,
#   'neg_sentiment': 0.5},
#  '2005-09-14': {'edit_count': 3,
#   'sentiment': -0.9723564783732096,
#   'neg_sentiment': 1.0},
#  '2005-09-15': {'edit_count': 5,
#   'sentiment': 0.055794358253479004,
#   'neg_sentiment': 0.4},
#  '2005-09-16': {'edit_count': 1,
#   'sentiment': -0.9992408752441406,
#   'neg_sentiment': 1.0},
#  '2005-09-17': {'edit_count': 1,
#   'sentiment': -0.9884297847747803,
#   'neg_sentiment': 1.0},
#  '2005-09-18': {'edit_count': 3,
#   'sentiment': -0.42775068680445355,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-09-19': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-09-20': {'edit_count': 1,
#   'sentiment': -0.9884297847747803,
#   'neg_sentiment': 1.0},
#  '2005-09-21': {'edit_count': 3,
#   'sentiment': 0.2445063591003418,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-09-23': {'edit_count': 1,
#   'sentiment': 0.6941739916801453,
#   'neg_sentiment': 0.0},
#  '2005-09-24': {'edit_count': 1,
#   'sentiment': -0.9713435173034668,
#   'neg_sentiment': 1.0},
#  '2005-09-25': {'edit_count': 3,
#   'sentiment': 0.3300680915514628,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-09-26': {'edit_count': 2,
#   'sentiment': -0.0017651915550231934,
#   'neg_sentiment': 0.5},
#  '2005-09-30': {'edit_count': 1,
#   'sentiment': 0.9819003343582153,
#   'neg_sentiment': 0.0},
#  '2005-10-01': {'edit_count': 5,
#   'sentiment': -0.5919838666915893,
#   'neg_sentiment': 0.8},
#  '2005-10-05': {'edit_count': 3,
#   'sentiment': 0.1655275821685791,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-10-07': {'edit_count': 2,
#   'sentiment': -0.026172995567321777,
#   'neg_sentiment': 0.5},
#  '2005-10-08': {'edit_count': 2,
#   'sentiment': -0.07317858934402466,
#   'neg_sentiment': 0.5},
#  '2005-10-10': {'edit_count': 2,
#   'sentiment': -0.12390679121017456,
#   'neg_sentiment': 0.5},
#  '2005-10-11': {'edit_count': 3,
#   'sentiment': -0.3409118453661601,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-10-12': {'edit_count': 3,
#   'sentiment': 0.17822853724161783,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-10-13': {'edit_count': 14,
#   'sentiment': -0.09661075472831726,
#   'neg_sentiment': 0.5},
#  '2005-10-14': {'edit_count': 1,
#   'sentiment': -0.9979584217071533,
#   'neg_sentiment': 1.0},
#  '2005-10-15': {'edit_count': 2,
#   'sentiment': -0.1016528308391571,
#   'neg_sentiment': 0.5},
#  '2005-10-16': {'edit_count': 3,
#   'sentiment': -0.9695363839467367,
#   'neg_sentiment': 1.0},
#  '2005-10-17': {'edit_count': 4,
#   'sentiment': -0.5031508654356003,
#   'neg_sentiment': 0.75},
#  '2005-10-18': {'edit_count': 6,
#   'sentiment': -0.6633768677711487,
#   'neg_sentiment': 0.8333333333333334},
#  '2005-10-19': {'edit_count': 3,
#   'sentiment': -0.9245628317197164,
#   'neg_sentiment': 1.0},
#  '2005-10-20': {'edit_count': 6,
#   'sentiment': -0.0633545716603597,
#   'neg_sentiment': 0.5},
#  '2005-10-22': {'edit_count': 1,
#   'sentiment': -0.5302705764770508,
#   'neg_sentiment': 1.0},
#  '2005-10-23': {'edit_count': 3,
#   'sentiment': 0.17629734675089517,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-10-25': {'edit_count': 1,
#   'sentiment': -0.9981313347816467,
#   'neg_sentiment': 1.0},
#  '2005-10-26': {'edit_count': 7,
#   'sentiment': 0.31359115668705534,
#   'neg_sentiment': 0.2857142857142857},
#  '2005-10-27': {'edit_count': 3,
#   'sentiment': -0.3722018798192342,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-10-28': {'edit_count': 2,
#   'sentiment': -0.9713435173034668,
#   'neg_sentiment': 1.0},
#  '2005-10-29': {'edit_count': 1,
#   'sentiment': -0.9696530103683472,
#   'neg_sentiment': 1.0},
#  '2005-10-30': {'edit_count': 3,
#   'sentiment': 0.20880117019017538,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-10-31': {'edit_count': 4,
#   'sentiment': -0.5054055154323578,
#   'neg_sentiment': 0.75},
#  '2005-11-01': {'edit_count': 6,
#   'sentiment': 0.059074570735295616,
#   'neg_sentiment': 0.5},
#  '2005-11-02': {'edit_count': 2,
#   'sentiment': -0.9664499759674072,
#   'neg_sentiment': 1.0},
#  '2005-11-04': {'edit_count': 1,
#   'sentiment': -0.8942376971244812,
#   'neg_sentiment': 1.0},
#  '2005-11-05': {'edit_count': 3,
#   'sentiment': -0.41578932603200275,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-11-06': {'edit_count': 4,
#   'sentiment': -0.42359550297260284,
#   'neg_sentiment': 0.75},
#  '2005-11-07': {'edit_count': 3,
#   'sentiment': -0.46208558479944867,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-11-09': {'edit_count': 7,
#   'sentiment': 0.30933672189712524,
#   'neg_sentiment': 0.2857142857142857},
#  '2005-11-13': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-11-16': {'edit_count': 2,
#   'sentiment': -0.12398752570152283,
#   'neg_sentiment': 0.5},
#  '2005-11-17': {'edit_count': 3,
#   'sentiment': 0.1667375167210897,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-11-19': {'edit_count': 3,
#   'sentiment': 0.7011121908823649,
#   'neg_sentiment': 0.0},
#  '2005-11-20': {'edit_count': 4,
#   'sentiment': 0.015605390071868896,
#   'neg_sentiment': 0.5},
#  '2005-11-22': {'edit_count': 3,
#   'sentiment': -0.4139555096626282,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-11-23': {'edit_count': 1,
#   'sentiment': -0.9984121322631836,
#   'neg_sentiment': 1.0},
#  '2005-11-24': {'edit_count': 3,
#   'sentiment': -0.9549773931503296,
#   'neg_sentiment': 1.0},
#  '2005-11-25': {'edit_count': 7,
#   'sentiment': -0.4189377341951643,
#   'neg_sentiment': 0.7142857142857143},
#  '2005-11-26': {'edit_count': 3,
#   'sentiment': -0.41681357224782306,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-11-27': {'edit_count': 7,
#   'sentiment': 0.1272945318903242,
#   'neg_sentiment': 0.42857142857142855},
#  '2005-11-28': {'edit_count': 3,
#   'sentiment': 0.8896592060724894,
#   'neg_sentiment': 0.0},
#  '2005-11-29': {'edit_count': 4,
#   'sentiment': -0.43638890981674194,
#   'neg_sentiment': 0.75},
#  '2005-11-30': {'edit_count': 5,
#   'sentiment': 0.7432981729507446,
#   'neg_sentiment': 0.0},
#  '2005-12-01': {'edit_count': 1,
#   'sentiment': 0.9908351898193359,
#   'neg_sentiment': 0.0},
#  '2005-12-02': {'edit_count': 2,
#   'sentiment': -0.967965692281723,
#   'neg_sentiment': 1.0},
#  '2005-12-03': {'edit_count': 1,
#   'sentiment': -0.9838083386421204,
#   'neg_sentiment': 1.0},
#  '2005-12-05': {'edit_count': 5,
#   'sentiment': -0.21316107511520385,
#   'neg_sentiment': 0.6},
#  '2005-12-07': {'edit_count': 7,
#   'sentiment': 0.05038184779030936,
#   'neg_sentiment': 0.42857142857142855},
#  '2005-12-08': {'edit_count': 3,
#   'sentiment': -0.32503819465637207,
#   'neg_sentiment': 0.6666666666666666},
#  '2005-12-09': {'edit_count': 5,
#   'sentiment': -0.307637882232666,
#   'neg_sentiment': 0.6},
#  '2005-12-10': {'edit_count': 7,
#   'sentiment': 0.47683900594711304,
#   'neg_sentiment': 0.14285714285714285},
#  '2005-12-11': {'edit_count': 10,
#   'sentiment': -0.8070210576057434,
#   'neg_sentiment': 0.9},
#  '2005-12-12': {'edit_count': 5,
#   'sentiment': 0.16837085485458375,
#   'neg_sentiment': 0.4},
#  '2005-12-15': {'edit_count': 1,
#   'sentiment': 0.7481210231781006,
#   'neg_sentiment': 0.0},
#  '2005-12-16': {'edit_count': 6,
#   'sentiment': 0.16152586539586386,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-12-17': {'edit_count': 13,
#   'sentiment': -0.16882368692984948,
#   'neg_sentiment': 0.5384615384615384},
#  '2005-12-18': {'edit_count': 11,
#   'sentiment': -0.047209203243255615,
#   'neg_sentiment': 0.5454545454545454},
#  '2005-12-19': {'edit_count': 13,
#   'sentiment': 0.20078599452972412,
#   'neg_sentiment': 0.38461538461538464},
#  '2005-12-20': {'edit_count': 4,
#   'sentiment': -0.5026235580444336,
#   'neg_sentiment': 0.75},
#  '2005-12-21': {'edit_count': 9,
#   'sentiment': 0.25567830933464897,
# ...
#   'sentiment': -0.17791442945599556,
#   'neg_sentiment': 0.5625},
#  '2007-01-09': {'edit_count': 67,
#   'sentiment': 0.10031542493336236,
#   'neg_sentiment': 0.43283582089552236},
#  '2007-01-10': {'edit_count': 56,
#   'sentiment': -0.19281176051923207,
#   'neg_sentiment': 0.5892857142857143},
#  '2007-01-11': {'edit_count': 28,
#   'sentiment': -0.035501650401524136,
#   'neg_sentiment': 0.5},
#  '2007-01-12': {'edit_count': 8,
#   'sentiment': 0.12928506731987,
#   'neg_sentiment': 0.375},
#  '2007-01-13': {'edit_count': 24,
#   'sentiment': 0.40334813048442203,
#   'neg_sentiment': 0.20833333333333334},
#  '2007-01-14': {'edit_count': 7,
#   'sentiment': 0.13286750657217844,
#   'neg_sentiment': 0.42857142857142855},
#  '2007-01-15': {'edit_count': 13,
#   'sentiment': -0.08605548510184655,
#   'neg_sentiment': 0.5384615384615384},
#  '2007-01-16': {'edit_count': 8,
#   'sentiment': 0.09459196031093597,
#   'neg_sentiment': 0.375},
#  '2007-01-17': {'edit_count': 8,
#   'sentiment': 0.008444339036941528,
#   'neg_sentiment': 0.5},
#  '2007-01-18': {'edit_count': 15,
#   'sentiment': 0.17804069916407267,
#   'neg_sentiment': 0.4},
#  '2007-01-19': {'edit_count': 20,
#   'sentiment': -0.05859041512012482,
#   'neg_sentiment': 0.5},
#  '2007-01-20': {'edit_count': 8,
#   'sentiment': 0.20125623047351837,
#   'neg_sentiment': 0.375},
#  '2007-01-21': {'edit_count': 5,
#   'sentiment': 0.5460500597953797,
#   'neg_sentiment': 0.2},
#  '2007-01-22': {'edit_count': 6,
#   'sentiment': -0.6678561170895895,
#   'neg_sentiment': 0.8333333333333334},
#  '2007-01-23': {'edit_count': 12,
#   'sentiment': 0.07075828810532887,
#   'neg_sentiment': 0.4166666666666667},
#  '2007-01-24': {'edit_count': 9,
#   'sentiment': -0.4694043927722507,
#   'neg_sentiment': 0.7777777777777778},
#  '2007-01-25': {'edit_count': 7,
#   'sentiment': 0.09737996544156756,
#   'neg_sentiment': 0.42857142857142855},
#  '2007-01-26': {'edit_count': 4,
#   'sentiment': -0.12542349100112915,
#   'neg_sentiment': 0.5},
#  '2007-01-27': {'edit_count': 7,
#   'sentiment': -0.00016210760389055525,
#   'neg_sentiment': 0.42857142857142855},
#  '2007-01-28': {'edit_count': 7,
#   'sentiment': -0.2985717994826181,
#   'neg_sentiment': 0.7142857142857143},
#  '2007-01-29': {'edit_count': 15,
#   'sentiment': 0.12210165659586589,
#   'neg_sentiment': 0.4},
#  '2007-01-30': {'edit_count': 7,
#   'sentiment': 0.02856640304837908,
#   'neg_sentiment': 0.42857142857142855},
#  '2007-01-31': {'edit_count': 11,
#   'sentiment': -0.36127412861043756,
#   'neg_sentiment': 0.6363636363636364},
#  '2007-02-01': {'edit_count': 23,
#   'sentiment': -0.33155259101287177,
#   'neg_sentiment': 0.6521739130434783},
#  '2007-02-02': {'edit_count': 19,
#   'sentiment': -0.8180487846073351,
#   'neg_sentiment': 0.8947368421052632},
#  '2007-02-03': {'edit_count': 16,
#   'sentiment': -0.12008042261004448,
#   'neg_sentiment': 0.5625},
#  '2007-02-04': {'edit_count': 7,
#   'sentiment': -0.19084649426596506,
#   'neg_sentiment': 0.5714285714285714},
#  '2007-02-05': {'edit_count': 18,
#   'sentiment': -0.6509053309758505,
#   'neg_sentiment': 0.8333333333333334},
#  '2007-02-06': {'edit_count': 21,
#   'sentiment': -0.14963684195563906,
#   'neg_sentiment': 0.5238095238095238},
#  '2007-02-07': {'edit_count': 8,
#   'sentiment': 0.14588767290115356,
#   'neg_sentiment': 0.375},
#  '2007-02-08': {'edit_count': 6,
#   'sentiment': -0.04197541872660319,
#   'neg_sentiment': 0.5},
#  '2007-02-09': {'edit_count': 7,
#   'sentiment': 0.0709700073514666,
#   'neg_sentiment': 0.42857142857142855},
#  '2007-02-10': {'edit_count': 3,
#   'sentiment': -0.33144547541936237,
#   'neg_sentiment': 0.6666666666666666},
#  '2007-02-11': {'edit_count': 14,
#   'sentiment': -0.06247695428984506,
#   'neg_sentiment': 0.5},
#  '2007-02-12': {'edit_count': 6,
#   'sentiment': 0.4985869924227397,
#   'neg_sentiment': 0.16666666666666666},
#  '2007-02-13': {'edit_count': 10,
#   'sentiment': 0.31375707387924195,
#   'neg_sentiment': 0.3},
#  '2007-02-14': {'edit_count': 19,
#   'sentiment': -0.3097196723285474,
#   'neg_sentiment': 0.631578947368421},
#  '2007-02-15': {'edit_count': 6,
#   'sentiment': 0.14352819323539734,
#   'neg_sentiment': 0.3333333333333333},
#  '2007-02-16': {'edit_count': 10,
#   'sentiment': -0.4281053483486176,
#   'neg_sentiment': 0.7},
#  '2007-02-17': {'edit_count': 9,
#   'sentiment': 0.00015795230865478516,
#   'neg_sentiment': 0.4444444444444444},
#  '2007-02-18': {'edit_count': 13,
#   'sentiment': 0.06674262652030358,
#   'neg_sentiment': 0.46153846153846156},
#  '2007-02-19': {'edit_count': 6,
#   'sentiment': -0.04273627201716105,
#   'neg_sentiment': 0.5},
#  '2007-02-20': {'edit_count': 7,
#   'sentiment': 0.11633636270250593,
#   'neg_sentiment': 0.42857142857142855},
#  '2007-02-21': {'edit_count': 11,
#   'sentiment': 0.20853216539729724,
#   'neg_sentiment': 0.36363636363636365},
#  '2007-02-22': {'edit_count': 8,
#   'sentiment': 0.18747150897979736,
#   'neg_sentiment': 0.375},
#  '2007-02-23': {'edit_count': 8,
#   'sentiment': 0.17158830910921097,
#   'neg_sentiment': 0.375},
#  '2007-02-24': {'edit_count': 6,
#   'sentiment': 0.41957126061121625,
#   'neg_sentiment': 0.3333333333333333},
#  '2007-02-25': {'edit_count': 9,
#   'sentiment': 0.16886022355821398,
#   'neg_sentiment': 0.3333333333333333},
#  '2007-02-26': {'edit_count': 8,
#   'sentiment': -0.0668790191411972,
#   'neg_sentiment': 0.5},
#  '2007-02-27': {'edit_count': 15,
#   'sentiment': -0.18308939933776855,
#   'neg_sentiment': 0.6},
#  '2007-02-28': {'edit_count': 9,
#   'sentiment': -0.19323068857192993,
#   'neg_sentiment': 0.5555555555555556},
#  '2007-03-01': {'edit_count': 20,
#   'sentiment': -0.08379515707492828,
#   'neg_sentiment': 0.5},
#  '2007-03-02': {'edit_count': 7,
#   'sentiment': -0.9210155776568821,
#   'neg_sentiment': 1.0},
#  '2007-03-04': {'edit_count': 9,
#   'sentiment': 0.2057925197813246,
#   'neg_sentiment': 0.3333333333333333},
#  '2007-03-05': {'edit_count': 17,
#   'sentiment': 0.11850687686134787,
#   'neg_sentiment': 0.4117647058823529},
#  '2007-03-06': {'edit_count': 20,
#   'sentiment': 0.049270224571228025,
#   'neg_sentiment': 0.45},
#  '2007-03-07': {'edit_count': 4,
#   'sentiment': -0.12393800914287567,
#   'neg_sentiment': 0.5},
#  '2007-03-08': {'edit_count': 20,
#   'sentiment': -0.08359472751617432,
#   'neg_sentiment': 0.55},
#  '2007-03-09': {'edit_count': 13,
#   'sentiment': 0.02090453184567965,
#   'neg_sentiment': 0.46153846153846156},
#  '2007-03-10': {'edit_count': 9,
#   'sentiment': -0.17429329289330375,
#   'neg_sentiment': 0.5555555555555556},
#  '2007-03-11': {'edit_count': 5,
#   'sentiment': 0.06587468385696411,
#   'neg_sentiment': 0.4},
#  '2007-03-12': {'edit_count': 4,
#   'sentiment': -0.003790438175201416,
#   'neg_sentiment': 0.5},
#  '2007-03-13': {'edit_count': 2,
#   'sentiment': -0.12445718050003052,
#   'neg_sentiment': 0.5},
#  '2007-03-14': {'edit_count': 6,
#   'sentiment': -0.34768569469451904,
#   'neg_sentiment': 0.6666666666666666},
#  '2007-03-16': {'edit_count': 13,
#   'sentiment': -0.17033068491862371,
#   'neg_sentiment': 0.6153846153846154},
#  '2007-03-17': {'edit_count': 4,
#   'sentiment': 0.0188303142786026,
#   'neg_sentiment': 0.5},
#  '2007-03-18': {'edit_count': 5,
#   'sentiment': 0.16401844024658202,
#   'neg_sentiment': 0.4},
#  '2007-03-19': {'edit_count': 14,
#   'sentiment': -0.18176043033599854,
#   'neg_sentiment': 0.5714285714285714},
#  '2007-03-20': {'edit_count': 12,
#   'sentiment': 0.05659701426823934,
#   'neg_sentiment': 0.4166666666666667},
#  '2007-03-21': {'edit_count': 10,
#   'sentiment': -0.22666236758232117,
#   'neg_sentiment': 0.6},
#  '2007-03-22': {'edit_count': 8,
#   'sentiment': -0.2309582382440567,
#   'neg_sentiment': 0.625},
#  '2007-03-23': {'edit_count': 10,
#   'sentiment': -0.0815855860710144,
#   'neg_sentiment': 0.5},
#  '2007-03-24': {'edit_count': 1,
#   'sentiment': -0.9242812991142273,
#   'neg_sentiment': 1.0},
#  '2007-03-25': {'edit_count': 9,
#   'sentiment': -0.373352931605445,
#   'neg_sentiment': 0.6666666666666666},
#  '2007-03-26': {'edit_count': 12,
#   'sentiment': 0.43099622925122577,
#   'neg_sentiment': 0.25},
#  '2007-03-27': {'edit_count': 5,
#   'sentiment': -0.5067146182060241,
#   'neg_sentiment': 0.8},
#  '2007-03-28': {'edit_count': 9,
#   'sentiment': -0.3612533211708069,
#   'neg_sentiment': 0.6666666666666666},
#  '2007-03-29': {'edit_count': 7,
#   'sentiment': -0.5645587699753898,
#   'neg_sentiment': 0.8571428571428571},
#  '2007-03-30': {'edit_count': 8,
#   'sentiment': 0.17492331564426422,
#   'neg_sentiment': 0.375},
#  '2007-03-31': {'edit_count': 4,
#   'sentiment': 0.9635771214962006,
#   'neg_sentiment': 0.0},
#  '2007-04-01': {'edit_count': 6,
#   'sentiment': 0.9263496100902557,
#   'neg_sentiment': 0.0},
#  '2007-04-03': {'edit_count': 13,
#   'sentiment': -0.02399191031089196,
#   'neg_sentiment': 0.46153846153846156},
#  '2007-04-04': {'edit_count': 11,
#   'sentiment': 0.013651907444000244,
#   'neg_sentiment': 0.45454545454545453},
#  '2007-04-05': {'edit_count': 9,
#   'sentiment': -0.16744393110275269,
#   'neg_sentiment': 0.5555555555555556},
#  '2007-04-06': {'edit_count': 5,
#   'sentiment': 0.49794842004776,
#   'neg_sentiment': 0.2},
#  '2007-04-07': {'edit_count': 7,
#   'sentiment': 0.38502213784626554,
#   'neg_sentiment': 0.2857142857142857},
#  '2007-04-08': {'edit_count': 8,
#   'sentiment': -0.24782340228557587,
#   'neg_sentiment': 0.625},
#  '2007-04-09': {'edit_count': 6,
#   'sentiment': -0.11471137404441833,
#   'neg_sentiment': 0.5},
#  '2007-04-10': {'edit_count': 16,
#   'sentiment': 0.4711149334907532,
#   'neg_sentiment': 0.25},
#  '2007-04-11': {'edit_count': 13,
#   'sentiment': 0.010967772740584154,
#   'neg_sentiment': 0.46153846153846156},
#  '2007-04-12': {'edit_count': 1,
#   'sentiment': -0.9988278746604919,
#   'neg_sentiment': 1.0},
#  '2007-04-13': {'edit_count': 2,
#   'sentiment': -0.0010436773300170898,
#   'neg_sentiment': 0.5},
#  '2007-04-15': {'edit_count': 10,
#   'sentiment': -0.04345300793647766,
#   'neg_sentiment': 0.5},
#  '2007-04-16': {'edit_count': 10,
#   'sentiment': -0.26771060824394227,
#   'neg_sentiment': 0.6},
#  '2007-04-17': {'edit_count': 14,
#   'sentiment': -0.5709783860615322,
#   'neg_sentiment': 0.7857142857142857},
#  '2007-04-18': {'edit_count': 13,
#   'sentiment': -0.17300634200756365,
#   'neg_sentiment': 0.5384615384615384},
#  '2007-04-19': {'edit_count': 17,
#   'sentiment': -0.7804522339035483,
#   'neg_sentiment': 0.8823529411764706},
#  '2007-04-20': {'edit_count': 2,
#   'sentiment': -0.9951288402080536,
#   'neg_sentiment': 1.0},
#  '2007-04-21': {'edit_count': 4,
#   'sentiment': 0.3121454417705536,
#   'neg_sentiment': 0.25},
#  '2007-04-22': {'edit_count': 18,
#   'sentiment': -0.42806804842419094,
#   'neg_sentiment': 0.7222222222222222},
#  '2007-04-23': {'edit_count': 5,
#   'sentiment': -0.5943625569343567,
#   'neg_sentiment': 0.8},
#  '2007-04-24': {'edit_count': 12,
#   'sentiment': -0.28055888414382935,
#   'neg_sentiment': 0.5833333333333334},
#  '2007-04-25': {'edit_count': 3,
#   'sentiment': -0.32860058546066284,
#   'neg_sentiment': 0.6666666666666666},
#  '2007-04-26': {'edit_count': 18,
#   'sentiment': 0.12072360184457567,
#   'neg_sentiment': 0.3888888888888889},
#  '2007-04-27': {'edit_count': 4,
#   'sentiment': -0.10553579032421112,
#   'neg_sentiment': 0.5},
#  '2007-04-28': {'edit_count': 4,
#   'sentiment': -0.06959806382656097,
#   'neg_sentiment': 0.5},
#  '2007-04-29': {'edit_count': 12,
#   'sentiment': -0.7968146453301111,
#   'neg_sentiment': 0.9166666666666666},
#  '2007-04-30': {'edit_count': 29,
#   'sentiment': -0.3736800428094535,
#   'neg_sentiment': 0.6551724137931034},
#  '2007-05-01': {'edit_count': 16,
#   'sentiment': -0.04154697805643082,
#   'neg_sentiment': 0.5},
#  '2007-05-02': {'edit_count': 14,
#   'sentiment': -0.053756424358912876,
#   'neg_sentiment': 0.5},
#  '2007-05-03': {'edit_count': 4,
#   'sentiment': -0.997533455491066,
#   'neg_sentiment': 1.0},
#  '2007-05-04': {'edit_count': 4,
#   'sentiment': -0.5594930648803711,
#   'neg_sentiment': 0.75},
#  '2007-05-05': {'edit_count': 12,
#   'sentiment': -0.3624048928419749,
#   'neg_sentiment': 0.6666666666666666},
#  '2007-05-06': {'edit_count': 7,
#   'sentiment': 0.11837384530476161,
#   'neg_sentiment': 0.42857142857142855},
#  '2007-05-07': {'edit_count': 2,
#   'sentiment': -0.017221271991729736,
#   'neg_sentiment': 0.5},
#  '2007-05-08': {'edit_count': 23,
#   'sentiment': -0.6447189087453096,
#   'neg_sentiment': 0.8260869565217391},
#  '2007-05-09': {'edit_count': 28,
#   'sentiment': -0.7192645754132952,
#   'neg_sentiment': 0.8571428571428571},
#  '2007-05-10': {'edit_count': 8,
#   'sentiment': -0.0503799244761467,
#   'neg_sentiment': 0.5},
#  '2007-05-11': {'edit_count': 5,
#   'sentiment': -0.9564861297607422,
#   'neg_sentiment': 1.0},
#  '2007-05-12': {'edit_count': 11,
#   'sentiment': -0.6695594570853494,
#   'neg_sentiment': 0.8181818181818182},
#  '2007-05-13': {'edit_count': 1,
#   'sentiment': 0.987129271030426,
#   'neg_sentiment': 0.0},
#  '2007-05-14': {'edit_count': 18,
#   'sentiment': -0.7801148096720377,
#   'neg_sentiment': 0.8888888888888888},
#  '2007-05-15': {'edit_count': 32,
#   'sentiment': -0.6530692540109158,
#   'neg_sentiment': 0.8125},
#  '2007-05-16': {'edit_count': 9,
#   'sentiment': 0.033265146944257945,
#   'neg_sentiment': 0.4444444444444444},
#  '2007-05-17': {'edit_count': 11,
#   'sentiment': -0.47906172275543213,
#   'neg_sentiment': 0.7272727272727273},
#  '2007-05-18': {'edit_count': 4,
#   'sentiment': 0.9621597677469254,
#   'neg_sentiment': 0.0},
#  '2007-05-19': {'edit_count': 7,
#   'sentiment': -0.18470585346221924,
#   'neg_sentiment': 0.5714285714285714},
#  '2007-05-21': {'edit_count': 9,
#   'sentiment': -0.11218469672732884,
#   'neg_sentiment': 0.5555555555555556},
#  '2007-05-22': {'edit_count': 5,
#   'sentiment': -0.19388289451599122,
#   'neg_sentiment': 0.6},
#  '2007-05-23': {'edit_count': 19,
#   'sentiment': -0.11404152606662951,
#   'neg_sentiment': 0.5263157894736842},
#  '2007-05-24': {'edit_count': 8,
#   'sentiment': 0.12415457516908646,
#   'neg_sentiment': 0.375},
#  '2007-05-25': {'edit_count': 3,
#   'sentiment': 0.24399461348851523,
#   'neg_sentiment': 0.3333333333333333},
#  '2007-05-26': {'edit_count': 2,
#   'sentiment': -0.12289777398109436,
#   'neg_sentiment': 0.5},
#  '2007-05-29': {'edit_count': 13,
#   'sentiment': -0.9933364712274991,
#   'neg_sentiment': 1.0},
#  '2007-05-30': {'edit_count': 9,
#   'sentiment': 0.3432323800192939,
#   'neg_sentiment': 0.3333333333333333},
#  '2007-05-31': {'edit_count': 20,
#   'sentiment': -0.6196082592010498,
#   'neg_sentiment': 0.8},
#  '2007-06-01': {'edit_count': 17,
#   'sentiment': 0.008955580346724567,
#   'neg_sentiment': 0.47058823529411764},
#  '2007-06-02': {'edit_count': 13,
#   'sentiment': -0.34504934457632214,
#   'neg_sentiment': 0.6153846153846154},
#  '2007-06-03': {'edit_count': 11,
#   'sentiment': 0.009081900119781494,
#   'neg_sentiment': 0.45454545454545453},
#  '2007-06-04': {'edit_count': 6,
#   'sentiment': 0.857982724905014,
#   'neg_sentiment': 0.0},
#  '2007-06-05': {'edit_count': 13,
#   'sentiment': -0.28488420981627244,
#   'neg_sentiment': 0.6153846153846154},
#  '2007-06-06': {'edit_count': 7,
#   'sentiment': 0.060049746717725484,
#   'neg_sentiment': 0.42857142857142855},
#  '2007-06-07': {'edit_count': 1,
#   'sentiment': -0.993596076965332,
#   'neg_sentiment': 1.0},
#  '2007-06-08': {'edit_count': 3,
#   'sentiment': -0.38236385583877563,
#   'neg_sentiment': 0.6666666666666666},
#  '2007-06-09': {'edit_count': 6,
#   'sentiment': -0.04095873236656189,
#   'neg_sentiment': 0.5},
#  '2007-06-10': {'edit_count': 5,
#   'sentiment': 0.5619867444038391,
#   'neg_sentiment': 0.2},
#  '2007-06-11': {'edit_count': 7,
#   'sentiment': -0.4972449966839382,
#   'neg_sentiment': 0.7142857142857143},
#  '2007-06-12': {'edit_count': 5,
#   'sentiment': 0.0507103443145752,
#   'neg_sentiment': 0.4},
#  '2007-06-13': {'edit_count': 7,
#   'sentiment': 0.30506095715931486,
#   'neg_sentiment': 0.2857142857142857},
#  '2007-06-14': {'edit_count': 11,
#   'sentiment': -0.5190639441663568,
#   'neg_sentiment': 0.7272727272727273},
#  '2007-06-15': {'edit_count': 1,
#   'sentiment': -0.9881494045257568,
#   'neg_sentiment': 1.0},
#  '2007-06-16': {'edit_count': 3,
#   'sentiment': -0.9990129669507345,
#   'neg_sentiment': 1.0},
#  '2007-06-17': {'edit_count': 9,
#   'sentiment': 0.9332314928372701,
#   'neg_sentiment': 0.0},
#  '2007-06-18': {'edit_count': 7,
#   'sentiment': -0.48977633884974886,
#   'neg_sentiment': 0.7142857142857143},
#  '2007-06-19': {'edit_count': 5,
#   'sentiment': -0.33018767833709717,
#   'neg_sentiment': 0.6},
#  ...}

# %%
import pandas as pd

edits_df = pd.DataFrame.from_dict(edits, orient="index")

# %%
edits_df
# Out:
#             edit_count  sentiment  neg_sentiment
# 2001-11-03           2   0.988535       0.000000
# 2002-02-09           1   0.633079       0.000000
# 2002-02-11           2   0.864165       0.000000
# 2002-02-25           1   0.979635       0.000000
# 2002-03-01           3   0.346754       0.333333
# ...                ...        ...            ...
# 2024-07-22           7  -0.238651       0.571429
# 2024-07-27           2   0.934352       0.000000
# 2024-07-28           6   0.165639       0.333333
# 2024-07-29           5   0.893641       0.000000
# 2024-07-30           1   0.982073       0.000000
#
# [3895 rows x 3 columns]

# %%
# Convert the index of the DataFrame 'edits_df' to datetime format
edits_df.index = pd.to_datetime(edits_df.index)

# %%
from datetime import datetime

dates = pd.date_range(start="2001-10-24",end=datetime.today())

# %%
edits_df = edits_df.reindex(dates, fill_value=0)

# %%
edits_df
# Out:
#             edit_count  sentiment  neg_sentiment
# 2001-10-24           0        0.0            0.0
# 2001-10-25           0        0.0            0.0
# 2001-10-26           0        0.0            0.0
# 2001-10-27           0        0.0            0.0
# 2001-10-28           0        0.0            0.0
# ...                ...        ...            ...
# 2024-08-07           0        0.0            0.0
# 2024-08-08           0        0.0            0.0
# 2024-08-09           0        0.0            0.0
# 2024-08-10           0        0.0            0.0
# 2024-08-11           0        0.0            0.0
#
# [8328 rows x 3 columns]

# %%
# Calculate the rolling mean of the DataFrame 'edits_df' over a 30-day window.
# The 'min_periods=30' ensures that at least 30 data points are required for the calculation.
rolling_edits = edits_df.rolling(30, min_periods=30).mean()

# %%
rolling_edits
# Out:
#             edit_count  sentiment  neg_sentiment
# 2001-10-24         NaN        NaN            NaN
# 2001-10-25         NaN        NaN            NaN
# 2001-10-26         NaN        NaN            NaN
# 2001-10-27         NaN        NaN            NaN
# 2001-10-28         NaN        NaN            NaN
# ...                ...        ...            ...
# 2024-08-07    1.100000   0.008265       0.213492
# 2024-08-08    1.066667  -0.016672       0.213492
# 2024-08-09    1.033333  -0.041610       0.213492
# 2024-08-10    1.033333  -0.041610       0.213492
# 2024-08-11    1.000000  -0.008285       0.180159
#
# [8328 rows x 3 columns]

# %%
rolling_edits = rolling_edits.dropna()

# %%
rolling_edits
# Out:
#             edit_count  sentiment  neg_sentiment
# 2001-11-22    0.066667   0.032951       0.000000
# 2001-11-23    0.066667   0.032951       0.000000
# 2001-11-24    0.066667   0.032951       0.000000
# 2001-11-25    0.066667   0.032951       0.000000
# 2001-11-26    0.066667   0.032951       0.000000
# ...                ...        ...            ...
# 2024-08-07    1.100000   0.008265       0.213492
# 2024-08-08    1.066667  -0.016672       0.213492
# 2024-08-09    1.033333  -0.041610       0.213492
# 2024-08-10    1.033333  -0.041610       0.213492
# 2024-08-11    1.000000  -0.008285       0.180159
#
# [8299 rows x 3 columns]
